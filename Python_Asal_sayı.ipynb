# %% [markdown]
# <a href="https://colab.research.google.com/github/d-1320hasan/colab/blob/main/Python_Asal_say%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sayı = int(input("Bir sayı giriniz"))
toplam=0
for i in range(2,sayı):
  if sayı%i==0:
    toplam += 1
if toplam == 0:
      print("sayı asal")
else:
      print("sayı asal değil")
# Out:
# Bir sayı giriniz9
# sayı asal değil
